# %% [markdown]
# **0) Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
from google.colab import drive
drive.mount('/content/gdrive')
#!ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /content/gdrive/MyDrive

# %% [markdown]
# **1) Clone the Darknet to GoogleDrive**

# %%
# !git clone https://github.com/AlexeyAB/darknet '/content/gdrive/MyDrive/YOLO/darknet'

# %% [markdown]
# **2) Sample data preparation**

# %% [markdown]
# create a new folder named as custom_data, custom_weight in gdrive
# compile the trained data with zip extension and upload into custom_data folder

# %%
# upload your custom data (images.zip) into your custom_data in gdrive and use this command to extract the content
# !unzip '/content/gdrive/MyDrive/YOLO/custom_data/images.zip' -d '/content/gdrive/MyDrive/YOLO/custom_data'

# %%
# Once you extracted your custom data, you have to relocate the directory in these python files to be able to create train and test files
# %cd '/content/gdrive/MyDrive/YOLO/custom_data'
# !python creating-files-data-and-name.py
# !python creating-train-and-test-txt-files.py

# %%
# Rerun make command to gain permission from mydrive
# !make clean
# %cd '/content/gdrive/MyDrive/YOLO/darknet'
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile       # change makefile to have GPU and OPENCV enabled
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make

# %% [markdown]
# **3) Getting custom weight (can choose other YOLO version)**

# %%
# %cd '/content/gdrive/MyDrive/YOLO/custom_weight'
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.conv.29     # Yolov4-tiny: Download pretrained dataset/weight
#!wget https://pjreddie.com/media/files/darknet53.conv.74                                               # Yolov3

# %% [markdown]
# **4) Reconfig the configuration (base on what YOLO version u used) for YOLO training**

# %% [markdown]
# go to your gdrive find /content/gdrive/MyDrive/YOLO/darknet/cfg/yolov4-tiny.cfg, then edit those parameter:
#
# [net]
#
# width and height: based on your desired
#
# uncomment those if u looking for training
#
# #training
# batch = 2
#
# subdivisions = 8
#
# max_batches = class*2000
#
# steps = (max_batches * 0.8), (max_batches * 0.9)
#
#
# [yolo]
#
# classes = class
#
# before [yolo] find this, normally with value of 255 =>
# filters = (class+5)*3

# %% [markdown]
# **5) Train the dataset**

# %%
# install those if u have problem of libopencv4.2
# !sudo apt install cmake
# !sudo apt install libopencv-dev python3-opencv

# %%
# %cd '/content/gdrive/MyDrive/YOLO/darknet'
# !./darknet detector train /content/gdrive/MyDrive/YOLO/custom_data/labelled_data.data /content/gdrive/MyDrive/YOLO/darknet/cfg/yolov4-tiny.cfg /content/gdrive/MyDrive/YOLO/custom_weight/yolov4-tiny.conv.29 -dont_show

# %% [markdown]
# **6) Test your dataset ! and you ready to go !**

# %%
# Please reconfig your cfg if you want to test and locate your test image subject after locating weights
# %cd '/content/gdrive/MyDrive/YOLO/darknet'
# !./darknet detector test /content/gdrive/MyDrive/YOLO/custom_data/labelled_data.data /content/gdrive/MyDrive/YOLO/darknet/cfg/yolov4-tiny.cfg /content/gdrive/MyDrive/YOLO/darknet/backup/yolov4-tiny_last.weights /content/gdrive/MyDrive/YOLO/darknet/test/test1.jpg -dont_show
